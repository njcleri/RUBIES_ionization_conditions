# %%
import ratios_z
import ratios_ha
import ratios_o32
import line_coverage
import lines_z
import zhist
import linmix_fits

# %%
ratios_z.make_ratios_versus_redshift_plot()
ratios_ha.make_ratios_versus_Ha_plot()
ratios_o32.make_ratios_versus_O32_plot()
line_coverage.make_coverage_plot()
lines_z.make_luminosity_versus_redshift_plot()
zhist.make_redshift_histogram_plot()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/cbook.py:1762: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return math.isfinite(val)

# %%
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_NeIIIOII_versus_Ha_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_O32_versus_Ha_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_R23_versus_Ha_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_R23_versus_redshift_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_O32_versus_redshift_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_OIIIHb_versus_redshift_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_NeIIIOII_versus_redshift_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_OIIIHb_versus_redshift_less_than_5_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_OIIIHb_versus_redshift_greater_than_5_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_O32_versus_redshift_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_R23_versus_redshift_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_R23_versus_O32_linmix()))
print(linmix_fits.linmix_slope_and_intercept(linmix_fits.fit_NeIIIOII_versus_O32_linmix()))
# Out:
# y = -0.13984771064838558 +/- 0.04500508181266342x + 5.764794320219051 +/- 1.8859337152622844
# y = 0.23106923036841875 +/- 0.045405698105141654x + -9.146765566868599 +/- 1.9110056268286528
# y = 0.13389994357852986 +/- 0.03189026366133572x + -4.729978901033281 +/- 1.349072932291718
# y = 0.017518817780488832 +/- 0.007956812347342355x + 0.8559817692807004 +/- 0.03971593612000512
# y = 0.07252034783720346 +/- 0.013764082304138479x + 0.24674912597328835 +/- 0.06514692716535067
# y = 0.05822362329307561 +/- 0.00727910532122724x + 0.36862591551639023 +/- 0.03691019862089529
# y = -0.0035200264361722085 +/- 0.01498484794932677x + -0.055546629896868156 +/- 0.06352664509624831
# y = 0.14331997944919153 +/- 0.01879059474273719x + 0.12295327486789728 +/- 0.06339973425845957
# y = -0.0016794173396450802 +/- 0.01384280486284677x + 0.7251233601119098 +/- 0.08795158790633129
# y = 0.07253886044700535 +/- 0.01353997943971376x + 0.24569208581335775 +/- 0.06424011156380596
# ...
